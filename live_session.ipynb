# %%
from sklearn.gaussian_process.kernels import ConstantKernel as C, RBF
from sklearn.gaussian_process import GaussianProcessRegressor
import numpy
import matplotlib.pyplot as plt

# %%
# %run 3_GP_Setup.ipynb
# %run Week_6_Algorithms.ipynb

# %%
def f(x):
    return x * np.sin(x)
myEnv = GPEnv(0., 10., f, 1, 1)

# %%
rew, reg = GPUCB(100, myEnv, 0., 10.)
# Out:
# c:\Users\marti\anaconda3\Lib\site-packages\sklearn\gaussian_process\kernels.py:419: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(

# %%
plt.plot(rew.cumsum(), label='Reward')
plt.plot(reg.cumsum(), label = 'Regret')
plt.legend()
plt.show()
